# %% [markdown]
# ## Supplementary headline

# %%
# Supplementary data provided by DECD; not part of the data portal data set.
# These are third-party contracts, while the data portal contains only contracts
# overseen by the state agency.

import pandas as pd

# %%
extra = pd.read_excel("data/Partners Job Audit.xlsx")

# %%
extra
# Out:
#                            Job Audits - DECD Partners           Unnamed: 1
# 0                                             Company  Met/Not Met/Pending
# 1                               Peter S. Turello, LLC                  Met
# 2                             SECONN Fabrication, LLC                  Met
# 3             Story Forge Labs, LLC dba Killer Minnow                  Met
# 4                      The Mystic Cheese Company, LLC              Not Met
# 5                         Edward R. Muenzner CPA, LLC                  Met
# 6                  Marty Gilman, Inc. dba Gilman Gear                  Met
# 7                                 Southern NE Fishery              Not Met
# 8                                       AgroSci, Inc.                  Met
# 9                                        Telserv, LLC              Pending
# 10                            Penmar Industries, Inc.              Pending
# ...
