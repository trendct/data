# %%
import pandas as pd

# %%
class_change = pd.read_csv("https://raw.githubusercontent.com/pewresearch/middle-class-data/master/metro_class_share_change.csv")

# %%
class_change
# Out:
#       Id  GeoFips                                    Metro name  \
# 0      1    10420                                     Akron, OH
# 1      2    10580                   Albany-Schenectady-Troy, NY
# 2      3    10740                               Albuquerque, NM
# 3      4    10900             Allentown-Bethlehem-Easton, PA-NJ
# 4      5    11100                                  Amarillo, TX
# 5      6    11260                                 Anchorage, AK
# 6      7    11460                                 Ann Arbor, MI
# 7      8    11500              Anniston-Oxford-Jacksonville, AL
# 8      9    12060             Atlanta-Sandy Springs-Roswell, GA
# 9     10    12100                   Atlantic City-Hammonton, NJ
# 10    11    12220                            Auburn-Opelika, AL
# 11    12    12260                Augusta-Richmond County, GA-SC
# 12    13    12420                         Austin-Round Rock, TX
# 13    14    12540                               Bakersfield, CA
# ...

# %%
class_change[class_change["Metro name"].str.contains(", CT")]
# Out:
#       Id  GeoFips                                Metro name  \
# 28    29    14860           Bridgeport-Stamford-Norwalk, CT
# 83    84    25540  Hartford-West Hartford-East Hartford, CT
# 139  140    35300                     New Haven-Milford, CT
# 144  145    35980                    Norwich-New London, CT
#
#      2014 lower income share  2014 middle income share  \
# 28                     22.45                     45.55
# 83                     20.96                     49.30
# 139                    27.71                     49.96
# 144                    18.55                     52.80
#
#      2014 upper income share  2000 to 2014 lower income change  \
# 28                     32.00                              0.79
# 83                     29.73                              2.08
# 139                    22.33                              1.75
# 144                    28.65                              0.60
#
# ...
